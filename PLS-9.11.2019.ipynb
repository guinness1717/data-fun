# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns

# %%
fp_pls = '~/Desktop/ES-Misc/Data-Python/JPPL/pls_export.csv'

# %%
df = pd.read_csv(fp_pls)

# %%
df.head()
# Out:
#                                            Name fscs_id         City State  \
# 0              AKRON-SUMMIT CNTY PUBLIC LIBRARY  OH0002        AKRON    OH
# 1                   ALLEN COUNTY PUBLIC LIBRARY  IN0073   FORT WAYNE    IN
# 2               CENTRAL ARKANSAS LIBRARY SYSTEM  AR0001  LITTLE ROCK    AR
# 3       CHARLESTON COUNTY PUBLIC LIBRARY SYSTEM  SC0009   CHARLESTON    SC
# 4  CITY OF ST. LOUIS MUNICIPAL LIBRARY DISTRICT  MO0030    ST. LOUIS    MO
#
#    Locale code  service_area_population  central_libraries  branch_libraries  \
# 0           12                   377588                  1                17
# 1           11                   355329                  1                13
# 2           12                   311250                  1                13
# 3           12                   350209                  1                15
# 4           11                   319294                  1                16
#
# ...

# %%
df.columns
# Out:
# Index(['Name', 'fscs_id', 'City', 'State', 'Locale code',
#        'service_area_population', 'central_libraries', 'branch_libraries',
#        'bookmobiles', 'interlibrary_relationship', 'legal_basis',
#        'administrative_structure', 'fscs_definition', 'geographic_code',
#        'mls_librarian_staff', 'librarian_staff', 'other_staff', 'total_staff',
#        'local_revenue', 'state_revenue', 'federal_revenue', 'other_revenue',
#        'total_revenue', 'salaries', 'benefits', 'total_staff_expenditures',
#        'print_expenditures', 'electronic_expenditures',
#        'other_collection_expenditures', 'total_collection_expenditures',
#        'other_expenditures', 'total_expenditures', 'local_capital_revenue',
#        'state_capital_revenue', 'federal_capital_revenue',
#        'other_capital_revenue', 'total_capital_revenue',
#        'capital_expenditures', 'print_materials', 'ebooks', 'audio_materials',
#        'audio_downloads', 'video_materials', 'video_downloads',
# ...

# %%
df_d = df[['Name','City','State','service_area_population','branch_libraries','total_revenue','total_expenditures',
           'visits']]

# %%
df_d.groupby(['State','City']).sum()
# Out:
#                       service_area_population  branch_libraries  \
# State City
# AR    LITTLE ROCK                      311250                13
# CA    FAIRFIELD                        376073                 8
#       OAKLAND                          445796                17
#       SAN MATEO                        283032                12
# CO    CASTLE ROCK                      322017                 7
#       THORNTON                         377353                 7
# FL    PALATKA                          368097                23
# IN    FORT WAYNE                       355329                13
# KY    LEXINGTON                        314488                 5
# LA    METAIRIE                         436523                15
#       NEW ORLEANS                      391495                13
# MD    ELLICOTT CITY                    304580                 7
# MI    COMSTOCK PARK                    395660                18
# ...

# %%
sns.distplot(df_d.visits, bins=10)
plt.savefig('/Users/guinness17/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/visits_bin.svg')

# %%
sns.distplot(df_d.total_revenue, bins=10)
plt.savefig('/Users/guinness17/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/rev_bins.svg')

# %%
sns.distplot(df_d.branch_libraries, bins=20)
plt.savefig('/Users/guinness17/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/branch_bins.svg')

# %%
sns.scatterplot(y='total_revenue', x='service_area_population', data=df_d)

# %%
sns.relplot(x='total_revenue',y='total_expenditures', data=df_d, hue='branch_libraries')
plt.savefig('/Users/guinness17/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/rel_bins.svg')

# %%
df_d['rev_exp_diff'] = ''
df_d.rev_exp_diff = df_d.total_revenue - df_d.total_expenditures
# Out:
# /usr/local/Cellar/ipython/7.8.0/libexec/vendor/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df_d.to_csv(path_or_buf='~/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/re-exp-9.13.2019.csv')

# %%
df_v = df[['Name','City','State','total_programs', 'kids_programs', 'ya_programs','program_audience', 
           'kids_program_audience', 'ya_program_audience','visits']]

# %%
df_v.head()
# Out:
#                                            Name         City State  \
# 0              AKRON-SUMMIT CNTY PUBLIC LIBRARY        AKRON    OH
# 1                   ALLEN COUNTY PUBLIC LIBRARY   FORT WAYNE    IN
# 2               CENTRAL ARKANSAS LIBRARY SYSTEM  LITTLE ROCK    AR
# 3       CHARLESTON COUNTY PUBLIC LIBRARY SYSTEM   CHARLESTON    SC
# 4  CITY OF ST. LOUIS MUNICIPAL LIBRARY DISTRICT    ST. LOUIS    MO
#
#    total_programs  kids_programs  ya_programs  program_audience  \
# 0            9045           4243         2119            240000
# 1            6244           4566          998            181456
# 2            9148           5015         1941            250222
# 3            6525           3764         1030            215172
# 4            6523           3644          864            150147
#
#    kids_program_audience  ya_program_audience   visits
# 0                 142102                40050  2250508
# 1                 138010                23727  2512375
# ...

# %%
df_v_grouped = df_v.groupby(['State','Name']).sum()
df_v.to_csv(path_or_buf='~/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/grouped-9.13.2019.csv')

# %%
##cohorts = ['SAN MATEO COUNTY LIBRARIES','HOWARD COUNTY LIBRARY SYSTEM','EAST BATON ROUGE PARISH LIBRARY',
##          'HARFORD COUNTY PUBLIC LIBRARY','ROCHESTER PUBLIC LIBRARY','SHREVE MEMORIAL LIBRARY',
##          'CLEVELAND PUBLIC LIBRARY','FREDERICK COUNTY PUBLIC LIBRARIES','KANSAS CITY PUBLIC LIBRARY',
##          'LOUDOUN COUNTY PUBLIC LIBRARY','JEFFERSON PARISH LIBRARY']
df_cohorts = df_v.loc[df_v.Name.isin(['SAN MATEO COUNTY LIBRARIES','HOWARD COUNTY LIBRARY SYSTEM',
                                    'EAST BATON ROUGE PARISH LIBRARY','HARFORD COUNTY PUBLIC LIBRARY',
                                      'ROCHESTER PUBLIC LIBRARY','SHREVE MEMORIAL LIBRARY','CLEVELAND PUBLIC LIBRARY',
                                      'FREDERICK COUNTY PUBLIC LIBRARIES','KANSAS CITY PUBLIC LIBRARY',
                                      'LOUDOUN COUNTY PUBLIC LIBRARY','JEFFERSON PARISH LIBRARY'])]

# %%
df_cohorts.head()
# Out:
#                             Name           City State  total_programs  \
# 9   HOWARD COUNTY LIBRARY SYSTEM  ELLICOTT CITY    MD            8328
# 10      JEFFERSON PARISH LIBRARY       METAIRIE    LA            3003
# 24    SAN MATEO COUNTY LIBRARIES      SAN MATEO    CA           11480
#
#     kids_programs  ya_programs  program_audience  kids_program_audience  \
# 9            4887         1183            307691                 229759
# 10           1819          430             57950                  36870
# 24           7755         1209            317625                 254598
#
#     ya_program_audience   visits
# 9                 54072  2178738
# 10                 5350  4142175
# 24                26128  2281657

# %%
sns.distplot(df_v.total_programs, bins=15)
plt.savefig('/Users/guinness17/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/total_programs_bins.svg')
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(df_v.program_audience, bins=10)
plt.savefig('/Users/guinness17/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/program_aud_bins.svg')
# Out:
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_v.sort_values(by='visits', ascending=False)
# Out:
#                                             Name            City State  \
# 10                      JEFFERSON PARISH LIBRARY        METAIRIE    LA
# 11                         KENT DISTRICT LIBRARY   COMSTOCK PARK    MI
# 1                    ALLEN COUNTY PUBLIC LIBRARY      FORT WAYNE    IN
# 26                   TIMBERLAND REGIONAL LIBRARY        TUMWATER    WA
# 21                RICHLAND COUNTY PUBLIC LIBRARY        COLUMBIA    SC
# 24                    SAN MATEO COUNTY LIBRARIES       SAN MATEO    CA
# 0               AKRON-SUMMIT CNTY PUBLIC LIBRARY           AKRON    OH
# 23                     SAINT PAUL PUBLIC LIBRARY      SAINT PAUL    MN
# 9                   HOWARD COUNTY LIBRARY SYSTEM   ELLICOTT CITY    MD
# 13                        MADISON PUBLIC LIBRARY         MADISON    WI
# 2                CENTRAL ARKANSAS LIBRARY SYSTEM     LITTLE ROCK    AR
# 16                        OAKLAND PUBLIC LIBRARY         OAKLAND    CA
# ...

# %%
df_v.head()
# Out:
#                                            Name         City State  \
# 0              AKRON-SUMMIT CNTY PUBLIC LIBRARY        AKRON    OH
# 1                   ALLEN COUNTY PUBLIC LIBRARY   FORT WAYNE    IN
# 2               CENTRAL ARKANSAS LIBRARY SYSTEM  LITTLE ROCK    AR
# 3       CHARLESTON COUNTY PUBLIC LIBRARY SYSTEM   CHARLESTON    SC
# 4  CITY OF ST. LOUIS MUNICIPAL LIBRARY DISTRICT    ST. LOUIS    MO
#
#    total_programs  kids_programs  ya_programs  program_audience  \
# 0            9045           4243         2119            240000
# 1            6244           4566          998            181456
# 2            9148           5015         1941            250222
# 3            6525           3764         1030            215172
# 4            6523           3644          864            150147
#
#    kids_program_audience  ya_program_audience   visits
# 0                 142102                40050  2250508
# 1                 138010                23727  2512375
# ...

# %%
df_top_3 = df_v.loc[df_v.Name.isin(['JEFFERSON PARISH LIBRARY','KENT DISTRICT LIBRARY','ALLEN COUNTY PUBLIC LIBRARY'])]

# %%
df_top_3.to_csv(path_or_buf='~/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/top-3-9.13.2019.csv')

# %%
sns.barplot(y='Name', x='total_programs', data=df_top_3)

# %%
sns.barplot(y='Name',x='program_audience',data=df_top_3)

# %%
## need to melt the data to chart it the way I want
programs = ['total_programs', 'kids_programs', 'ya_programs', 'program_audience', 'kids_program_audience',
            'ya_program_audience']

df_top_3_m = pd.melt(df_top_3, id_vars='Name', value_vars=programs, var_name='Programs', value_name='Attendance')

# %%
df_top_3_m.head()
# Out:
#                           Name        Programs  Attendance
# 0  ALLEN COUNTY PUBLIC LIBRARY  total_programs        6244
# 1     JEFFERSON PARISH LIBRARY  total_programs        3003
# 2        KENT DISTRICT LIBRARY  total_programs        6241
# 3  ALLEN COUNTY PUBLIC LIBRARY   kids_programs        4566
# 4     JEFFERSON PARISH LIBRARY   kids_programs        1819

# %%
df_top_3_m.to_csv(path_or_buf='~/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/top-3-m-9.13.2019.csv')

# %%
sns.barplot(y='Programs', x='Attendance', hue='Name', data=df_top_3_m)
## what does audience mean? Does this mean how many attended?
plt.savefig('/Users/guinness17/Desktop/ES-Misc/Data-Python/Export-csv/JPPL/top_3_m.svg')
